# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Check if TensorFlow can access GPU hardware acceleration
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
else:
    print("No GPU found, using CPU for training.")
        
# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df["CLASSIFICATION"].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(application_df["CLASSIFICATION"].value_counts()[application_df["CLASSIFICATION"].value_counts() < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummy_df = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "CLASSIFICATION", 
                                                   "AFFILIATION", "USE_CASE", "ORGANIZATION", 
                                                   "INCOME_AMT", "SPECIAL_CONSIDERATIONS"])
dummy_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = dummy_df.drop(columns=["IS_SUCCESSFUL"]).values
y = dummy_df["IS_SUCCESSFUL"]
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()
print(X_train_scaled.shape[1])
# Defining input layer shape
nn.add(tf.keras.layers.Input(shape=(X_train_scaled.shape[1],)))

# First hidden layer
nn.add(tf.keras.layers.Dense(units=64, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=32, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# 43
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 64)                2816
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 4,929
# Trainable params: 4,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Callback to save the model's weights every 5 epochs
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model_weights_{epoch:02d}.weights.h5',
    save_weights_only=True,
    save_freq=5*len(X_train_scaled)
)

# %%
# Train the model, adjust the batch_size as needed if you run into memory issues
nn.fit(X_train_scaled, y_train, epochs=250, verbose=2, batch_size=1024, callbacks=[callback], validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/250
# 26/26 - 0s - loss: 0.6461 - accuracy: 0.6459 - 421ms/epoch - 16ms/step
# Epoch 2/250
# 26/26 - 0s - loss: 0.5744 - accuracy: 0.7213 - 77ms/epoch - 3ms/step
# Epoch 3/250
# 26/26 - 0s - loss: 0.5642 - accuracy: 0.7250 - 77ms/epoch - 3ms/step
# Epoch 4/250
# 26/26 - 0s - loss: 0.5603 - accuracy: 0.7285 - 81ms/epoch - 3ms/step
# Epoch 5/250
# 26/26 - 0s - loss: 0.5572 - accuracy: 0.7293 - 77ms/epoch - 3ms/step
# Epoch 6/250
# 26/26 - 0s - loss: 0.5551 - accuracy: 0.7289 - 79ms/epoch - 3ms/step
# Epoch 7/250
# 26/26 - 0s - loss: 0.5537 - accuracy: 0.7292 - 82ms/epoch - 3ms/step
# Epoch 8/250
# 26/26 - 0s - loss: 0.5524 - accuracy: 0.7295 - 79ms/epoch - 3ms/step
# Epoch 9/250
# 26/26 - 0s - loss: 0.5515 - accuracy: 0.7304 - 77ms/epoch - 3ms/step
# Epoch 10/250
# 26/26 - 0s - loss: 0.5505 - accuracy: 0.7292 - 75ms/epoch - 3ms/step
# Epoch 11/250
# 26/26 - 0s - loss: 0.5496 - accuracy: 0.7309 - 79ms/epoch - 3ms/step
# Epoch 12/250
# 26/26 - 0s - loss: 0.5490 - accuracy: 0.7311 - 77ms/epoch - 3ms/step
# Epoch 13/250
# 26/26 - 0s - loss: 0.5494 - accuracy: 0.7297 - 77ms/epoch - 3ms/step
# Epoch 14/250
# 26/26 - 0s - loss: 0.5483 - accuracy: 0.7304 - 70ms/epoch - 3ms/step
# Epoch 15/250
# 26/26 - 0s - loss: 0.5479 - accuracy: 0.7306 - 71ms/epoch - 3ms/step
# Epoch 16/250
# 26/26 - 0s - loss: 0.5471 - accuracy: 0.7306 - 68ms/epoch - 3ms/step
# Epoch 17/250
# 26/26 - 0s - loss: 0.5468 - accuracy: 0.7314 - 76ms/epoch - 3ms/step
# Epoch 18/250
# 26/26 - 0s - loss: 0.5462 - accuracy: 0.7325 - 76ms/epoch - 3ms/step
# Epoch 19/250
# 26/26 - 0s - loss: 0.5467 - accuracy: 0.7314 - 79ms/epoch - 3ms/step
# Epoch 20/250
# 26/26 - 0s - loss: 0.5461 - accuracy: 0.7320 - 76ms/epoch - 3ms/step
# Epoch 21/250
# 26/26 - 0s - loss: 0.5455 - accuracy: 0.7324 - 78ms/epoch - 3ms/step
# Epoch 22/250
# 26/26 - 0s - loss: 0.5453 - accuracy: 0.7334 - 67ms/epoch - 3ms/step
# Epoch 23/250
# 26/26 - 0s - loss: 0.5455 - accuracy: 0.7323 - 69ms/epoch - 3ms/step
# Epoch 24/250
# 26/26 - 0s - loss: 0.5446 - accuracy: 0.7329 - 101ms/epoch - 4ms/step
# Epoch 25/250
# 26/26 - 0s - loss: 0.5451 - accuracy: 0.7328 - 93ms/epoch - 4ms/step
# Epoch 26/250
# 26/26 - 0s - loss: 0.5445 - accuracy: 0.7330 - 87ms/epoch - 3ms/step
# Epoch 27/250
# 26/26 - 0s - loss: 0.5442 - accuracy: 0.7330 - 74ms/epoch - 3ms/step
# Epoch 28/250
# 26/26 - 0s - loss: 0.5441 - accuracy: 0.7329 - 69ms/epoch - 3ms/step
# Epoch 29/250
# 26/26 - 0s - loss: 0.5440 - accuracy: 0.7331 - 70ms/epoch - 3ms/step
# Epoch 30/250
# 26/26 - 0s - loss: 0.5439 - accuracy: 0.7336 - 72ms/epoch - 3ms/step
# Epoch 31/250
# 26/26 - 0s - loss: 0.5439 - accuracy: 0.7338 - 78ms/epoch - 3ms/step
# Epoch 32/250
# 26/26 - 0s - loss: 0.5447 - accuracy: 0.7323 - 73ms/epoch - 3ms/step
# Epoch 33/250
# 26/26 - 0s - loss: 0.5435 - accuracy: 0.7338 - 66ms/epoch - 3ms/step
# Epoch 34/250
# 26/26 - 0s - loss: 0.5434 - accuracy: 0.7343 - 76ms/epoch - 3ms/step
# Epoch 35/250
# 26/26 - 0s - loss: 0.5432 - accuracy: 0.7334 - 71ms/epoch - 3ms/step
# Epoch 36/250
# 26/26 - 0s - loss: 0.5432 - accuracy: 0.7342 - 67ms/epoch - 3ms/step
# Epoch 37/250
# 26/26 - 0s - loss: 0.5434 - accuracy: 0.7338 - 74ms/epoch - 3ms/step
# Epoch 38/250
# 26/26 - 0s - loss: 0.5432 - accuracy: 0.7339 - 72ms/epoch - 3ms/step
# Epoch 39/250
# 26/26 - 0s - loss: 0.5428 - accuracy: 0.7343 - 73ms/epoch - 3ms/step
# Epoch 40/250
# 26/26 - 0s - loss: 0.5440 - accuracy: 0.7331 - 67ms/epoch - 3ms/step
# Epoch 41/250
# 26/26 - 0s - loss: 0.5441 - accuracy: 0.7343 - 71ms/epoch - 3ms/step
# Epoch 42/250
# 26/26 - 0s - loss: 0.5426 - accuracy: 0.7339 - 73ms/epoch - 3ms/step
# Epoch 43/250
# 26/26 - 0s - loss: 0.5426 - accuracy: 0.7344 - 76ms/epoch - 3ms/step
# Epoch 44/250
# 26/26 - 0s - loss: 0.5422 - accuracy: 0.7353 - 73ms/epoch - 3ms/step
# Epoch 45/250
# 26/26 - 0s - loss: 0.5421 - accuracy: 0.7354 - 71ms/epoch - 3ms/step
# Epoch 46/250
# 26/26 - 0s - loss: 0.5419 - accuracy: 0.7351 - 63ms/epoch - 2ms/step
# Epoch 47/250
# 26/26 - 0s - loss: 0.5422 - accuracy: 0.7338 - 83ms/epoch - 3ms/step
# Epoch 48/250
# 26/26 - 0s - loss: 0.5413 - accuracy: 0.7353 - 78ms/epoch - 3ms/step
# Epoch 49/250
# 26/26 - 0s - loss: 0.5415 - accuracy: 0.7360 - 70ms/epoch - 3ms/step
# Epoch 50/250
# 26/26 - 0s - loss: 0.5413 - accuracy: 0.7347 - 75ms/epoch - 3ms/step
# Epoch 51/250
# 26/26 - 0s - loss: 0.5413 - accuracy: 0.7350 - 75ms/epoch - 3ms/step
# Epoch 52/250
# 26/26 - 0s - loss: 0.5412 - accuracy: 0.7362 - 71ms/epoch - 3ms/step
# Epoch 53/250
# 26/26 - 0s - loss: 0.5412 - accuracy: 0.7346 - 77ms/epoch - 3ms/step
# Epoch 54/250
# 26/26 - 0s - loss: 0.5409 - accuracy: 0.7367 - 75ms/epoch - 3ms/step
# Epoch 55/250
# 26/26 - 0s - loss: 0.5412 - accuracy: 0.7354 - 75ms/epoch - 3ms/step
# Epoch 56/250
# 26/26 - 0s - loss: 0.5410 - accuracy: 0.7353 - 80ms/epoch - 3ms/step
# Epoch 57/250
# 26/26 - 0s - loss: 0.5408 - accuracy: 0.7353 - 70ms/epoch - 3ms/step
# Epoch 58/250
# 26/26 - 0s - loss: 0.5410 - accuracy: 0.7346 - 72ms/epoch - 3ms/step
# Epoch 59/250
# 26/26 - 0s - loss: 0.5405 - accuracy: 0.7365 - 80ms/epoch - 3ms/step
# Epoch 60/250
# 26/26 - 0s - loss: 0.5408 - accuracy: 0.7371 - 96ms/epoch - 4ms/step
# Epoch 61/250
# 26/26 - 0s - loss: 0.5409 - accuracy: 0.7362 - 73ms/epoch - 3ms/step
# Epoch 62/250
# 26/26 - 0s - loss: 0.5415 - accuracy: 0.7356 - 75ms/epoch - 3ms/step
# Epoch 63/250
# 26/26 - 0s - loss: 0.5404 - accuracy: 0.7372 - 64ms/epoch - 2ms/step
# Epoch 64/250
# 26/26 - 0s - loss: 0.5401 - accuracy: 0.7364 - 85ms/epoch - 3ms/step
# Epoch 65/250
# 26/26 - 0s - loss: 0.5405 - accuracy: 0.7371 - 87ms/epoch - 3ms/step
# Epoch 66/250
# 26/26 - 0s - loss: 0.5402 - accuracy: 0.7362 - 78ms/epoch - 3ms/step
# Epoch 67/250
# 26/26 - 0s - loss: 0.5399 - accuracy: 0.7366 - 83ms/epoch - 3ms/step
# Epoch 68/250
# 26/26 - 0s - loss: 0.5398 - accuracy: 0.7351 - 74ms/epoch - 3ms/step
# Epoch 69/250
# 26/26 - 0s - loss: 0.5399 - accuracy: 0.7365 - 70ms/epoch - 3ms/step
# Epoch 70/250
# 26/26 - 0s - loss: 0.5392 - accuracy: 0.7375 - 75ms/epoch - 3ms/step
# Epoch 71/250
# 26/26 - 0s - loss: 0.5403 - accuracy: 0.7364 - 74ms/epoch - 3ms/step
# Epoch 72/250
# 26/26 - 0s - loss: 0.5395 - accuracy: 0.7365 - 73ms/epoch - 3ms/step
# Epoch 73/250
# 26/26 - 0s - loss: 0.5397 - accuracy: 0.7364 - 71ms/epoch - 3ms/step
# Epoch 74/250
# 26/26 - 0s - loss: 0.5392 - accuracy: 0.7365 - 70ms/epoch - 3ms/step
# Epoch 75/250
# 26/26 - 0s - loss: 0.5401 - accuracy: 0.7357 - 72ms/epoch - 3ms/step
# Epoch 76/250
# 26/26 - 0s - loss: 0.5395 - accuracy: 0.7376 - 81ms/epoch - 3ms/step
# Epoch 77/250
# 26/26 - 0s - loss: 0.5395 - accuracy: 0.7366 - 98ms/epoch - 4ms/step
# Epoch 78/250
# 26/26 - 0s - loss: 0.5398 - accuracy: 0.7367 - 81ms/epoch - 3ms/step
# Epoch 79/250
# 26/26 - 0s - loss: 0.5394 - accuracy: 0.7374 - 82ms/epoch - 3ms/step
# Epoch 80/250
# 26/26 - 0s - loss: 0.5391 - accuracy: 0.7370 - 75ms/epoch - 3ms/step
# Epoch 81/250
# 26/26 - 0s - loss: 0.5395 - accuracy: 0.7364 - 71ms/epoch - 3ms/step
# Epoch 82/250
# 26/26 - 0s - loss: 0.5389 - accuracy: 0.7374 - 76ms/epoch - 3ms/step
# Epoch 83/250
# 26/26 - 0s - loss: 0.5389 - accuracy: 0.7373 - 76ms/epoch - 3ms/step
# Epoch 84/250
# 26/26 - 0s - loss: 0.5387 - accuracy: 0.7372 - 89ms/epoch - 3ms/step
# Epoch 85/250
# 26/26 - 0s - loss: 0.5394 - accuracy: 0.7369 - 80ms/epoch - 3ms/step
# Epoch 86/250
# 26/26 - 0s - loss: 0.5394 - accuracy: 0.7365 - 78ms/epoch - 3ms/step
# Epoch 87/250
# 26/26 - 0s - loss: 0.5391 - accuracy: 0.7372 - 75ms/epoch - 3ms/step
# Epoch 88/250
# 26/26 - 0s - loss: 0.5389 - accuracy: 0.7376 - 69ms/epoch - 3ms/step
# Epoch 89/250
# 26/26 - 0s - loss: 0.5387 - accuracy: 0.7379 - 81ms/epoch - 3ms/step
# Epoch 90/250
# 26/26 - 0s - loss: 0.5390 - accuracy: 0.7374 - 86ms/epoch - 3ms/step
# Epoch 91/250
# 26/26 - 0s - loss: 0.5391 - accuracy: 0.7364 - 72ms/epoch - 3ms/step
# Epoch 92/250
# 26/26 - 0s - loss: 0.5387 - accuracy: 0.7378 - 81ms/epoch - 3ms/step
# Epoch 93/250
# 26/26 - 0s - loss: 0.5390 - accuracy: 0.7364 - 90ms/epoch - 3ms/step
# Epoch 94/250
# 26/26 - 0s - loss: 0.5389 - accuracy: 0.7369 - 90ms/epoch - 3ms/step
# Epoch 95/250
# 26/26 - 0s - loss: 0.5380 - accuracy: 0.7381 - 90ms/epoch - 3ms/step
# Epoch 96/250
# 26/26 - 0s - loss: 0.5394 - accuracy: 0.7374 - 72ms/epoch - 3ms/step
# Epoch 97/250
# 26/26 - 0s - loss: 0.5385 - accuracy: 0.7376 - 78ms/epoch - 3ms/step
# Epoch 98/250
# 26/26 - 0s - loss: 0.5377 - accuracy: 0.7374 - 74ms/epoch - 3ms/step
# Epoch 99/250
# 26/26 - 0s - loss: 0.5383 - accuracy: 0.7385 - 73ms/epoch - 3ms/step
# Epoch 100/250
# 26/26 - 0s - loss: 0.5385 - accuracy: 0.7365 - 69ms/epoch - 3ms/step
# Epoch 101/250
# 26/26 - 0s - loss: 0.5382 - accuracy: 0.7374 - 71ms/epoch - 3ms/step
# Epoch 102/250
# 26/26 - 0s - loss: 0.5378 - accuracy: 0.7372 - 72ms/epoch - 3ms/step
# Epoch 103/250
# 26/26 - 0s - loss: 0.5376 - accuracy: 0.7376 - 81ms/epoch - 3ms/step
# Epoch 104/250
# 26/26 - 0s - loss: 0.5382 - accuracy: 0.7367 - 94ms/epoch - 4ms/step
# Epoch 105/250
# 26/26 - 0s - loss: 0.5382 - accuracy: 0.7365 - 88ms/epoch - 3ms/step
# Epoch 106/250
# 26/26 - 0s - loss: 0.5378 - accuracy: 0.7379 - 87ms/epoch - 3ms/step
# Epoch 107/250
# 26/26 - 0s - loss: 0.5377 - accuracy: 0.7383 - 82ms/epoch - 3ms/step
# Epoch 108/250
# 26/26 - 0s - loss: 0.5375 - accuracy: 0.7378 - 68ms/epoch - 3ms/step
# Epoch 109/250
# 26/26 - 0s - loss: 0.5374 - accuracy: 0.7386 - 80ms/epoch - 3ms/step
# Epoch 110/250
# 26/26 - 0s - loss: 0.5376 - accuracy: 0.7380 - 78ms/epoch - 3ms/step
# Epoch 111/250
# 26/26 - 0s - loss: 0.5378 - accuracy: 0.7375 - 74ms/epoch - 3ms/step
# Epoch 112/250
# 26/26 - 0s - loss: 0.5379 - accuracy: 0.7383 - 74ms/epoch - 3ms/step
# Epoch 113/250
# 26/26 - 0s - loss: 0.5375 - accuracy: 0.7384 - 68ms/epoch - 3ms/step
# Epoch 114/250
# 26/26 - 0s - loss: 0.5374 - accuracy: 0.7374 - 76ms/epoch - 3ms/step
# Epoch 115/250
# 26/26 - 0s - loss: 0.5375 - accuracy: 0.7384 - 86ms/epoch - 3ms/step
# Epoch 116/250
# 26/26 - 0s - loss: 0.5373 - accuracy: 0.7377 - 84ms/epoch - 3ms/step
# Epoch 117/250
# 26/26 - 0s - loss: 0.5373 - accuracy: 0.7379 - 87ms/epoch - 3ms/step
# Epoch 118/250
# 26/26 - 0s - loss: 0.5371 - accuracy: 0.7386 - 79ms/epoch - 3ms/step
# Epoch 119/250
# 26/26 - 0s - loss: 0.5369 - accuracy: 0.7386 - 80ms/epoch - 3ms/step
# Epoch 120/250
# 26/26 - 0s - loss: 0.5370 - accuracy: 0.7386 - 77ms/epoch - 3ms/step
# Epoch 121/250
# 26/26 - 0s - loss: 0.5376 - accuracy: 0.7381 - 73ms/epoch - 3ms/step
# Epoch 122/250
# 26/26 - 0s - loss: 0.5366 - accuracy: 0.7382 - 66ms/epoch - 3ms/step
# Epoch 123/250
# 26/26 - 0s - loss: 0.5370 - accuracy: 0.7391 - 65ms/epoch - 2ms/step
# Epoch 124/250
# 26/26 - 0s - loss: 0.5370 - accuracy: 0.7373 - 66ms/epoch - 3ms/step
# Epoch 125/250
# 26/26 - 0s - loss: 0.5375 - accuracy: 0.7378 - 69ms/epoch - 3ms/step
# Epoch 126/250
# 26/26 - 0s - loss: 0.5371 - accuracy: 0.7378 - 71ms/epoch - 3ms/step
# Epoch 127/250
# 26/26 - 0s - loss: 0.5383 - accuracy: 0.7375 - 66ms/epoch - 3ms/step
# Epoch 128/250
# 26/26 - 0s - loss: 0.5378 - accuracy: 0.7379 - 72ms/epoch - 3ms/step
# Epoch 129/250
# 26/26 - 0s - loss: 0.5371 - accuracy: 0.7395 - 67ms/epoch - 3ms/step
# Epoch 130/250
# 26/26 - 0s - loss: 0.5371 - accuracy: 0.7376 - 73ms/epoch - 3ms/step
# Epoch 131/250
# 26/26 - 0s - loss: 0.5368 - accuracy: 0.7386 - 65ms/epoch - 2ms/step
# Epoch 132/250
# 26/26 - 0s - loss: 0.5369 - accuracy: 0.7388 - 73ms/epoch - 3ms/step
# Epoch 133/250
# 26/26 - 0s - loss: 0.5372 - accuracy: 0.7352 - 68ms/epoch - 3ms/step
# Epoch 134/250
# 26/26 - 0s - loss: 0.5368 - accuracy: 0.7390 - 69ms/epoch - 3ms/step
# Epoch 135/250
# 26/26 - 0s - loss: 0.5373 - accuracy: 0.7380 - 76ms/epoch - 3ms/step
# Epoch 136/250
# 26/26 - 0s - loss: 0.5367 - accuracy: 0.7379 - 79ms/epoch - 3ms/step
# Epoch 137/250
# 26/26 - 0s - loss: 0.5367 - accuracy: 0.7385 - 92ms/epoch - 4ms/step
# Epoch 138/250
# 26/26 - 0s - loss: 0.5369 - accuracy: 0.7391 - 76ms/epoch - 3ms/step
# Epoch 139/250
# 26/26 - 0s - loss: 0.5367 - accuracy: 0.7385 - 66ms/epoch - 3ms/step
# Epoch 140/250
# 26/26 - 0s - loss: 0.5366 - accuracy: 0.7387 - 63ms/epoch - 2ms/step
# Epoch 141/250
# 26/26 - 0s - loss: 0.5372 - accuracy: 0.7373 - 78ms/epoch - 3ms/step
# Epoch 142/250
# 26/26 - 0s - loss: 0.5367 - accuracy: 0.7378 - 80ms/epoch - 3ms/step
# Epoch 143/250
# 26/26 - 0s - loss: 0.5366 - accuracy: 0.7380 - 78ms/epoch - 3ms/step
# Epoch 144/250
# 26/26 - 0s - loss: 0.5363 - accuracy: 0.7394 - 78ms/epoch - 3ms/step
# Epoch 145/250
# 26/26 - 0s - loss: 0.5366 - accuracy: 0.7384 - 72ms/epoch - 3ms/step
# Epoch 146/250
# 26/26 - 0s - loss: 0.5364 - accuracy: 0.7377 - 71ms/epoch - 3ms/step
# Epoch 147/250
# 26/26 - 0s - loss: 0.5364 - accuracy: 0.7376 - 65ms/epoch - 2ms/step
# Epoch 148/250
# 26/26 - 0s - loss: 0.5363 - accuracy: 0.7392 - 71ms/epoch - 3ms/step
# Epoch 149/250
# 26/26 - 0s - loss: 0.5365 - accuracy: 0.7392 - 67ms/epoch - 3ms/step
# Epoch 150/250
# 26/26 - 0s - loss: 0.5361 - accuracy: 0.7390 - 73ms/epoch - 3ms/step
# Epoch 151/250
# 26/26 - 0s - loss: 0.5363 - accuracy: 0.7390 - 59ms/epoch - 2ms/step
# Epoch 152/250
# 26/26 - 0s - loss: 0.5364 - accuracy: 0.7389 - 61ms/epoch - 2ms/step
# Epoch 153/250
# 26/26 - 0s - loss: 0.5368 - accuracy: 0.7388 - 70ms/epoch - 3ms/step
# Epoch 154/250
# 26/26 - 0s - loss: 0.5361 - accuracy: 0.7387 - 68ms/epoch - 3ms/step
# Epoch 155/250
# 26/26 - 0s - loss: 0.5362 - accuracy: 0.7388 - 73ms/epoch - 3ms/step
# Epoch 156/250
# 26/26 - 0s - loss: 0.5370 - accuracy: 0.7395 - 71ms/epoch - 3ms/step
# Epoch 157/250
# 26/26 - 0s - loss: 0.5360 - accuracy: 0.7382 - 68ms/epoch - 3ms/step
# Epoch 158/250
# 26/26 - 0s - loss: 0.5354 - accuracy: 0.7400 - 64ms/epoch - 2ms/step
# Epoch 159/250
# 26/26 - 0s - loss: 0.5364 - accuracy: 0.7374 - 72ms/epoch - 3ms/step
# Epoch 160/250
# 26/26 - 0s - loss: 0.5360 - accuracy: 0.7380 - 71ms/epoch - 3ms/step
# Epoch 161/250
# 26/26 - 0s - loss: 0.5369 - accuracy: 0.7383 - 76ms/epoch - 3ms/step
# Epoch 162/250
# 26/26 - 0s - loss: 0.5359 - accuracy: 0.7371 - 73ms/epoch - 3ms/step
# Epoch 163/250
# 26/26 - 0s - loss: 0.5358 - accuracy: 0.7393 - 75ms/epoch - 3ms/step
# Epoch 164/250
# 26/26 - 0s - loss: 0.5362 - accuracy: 0.7383 - 72ms/epoch - 3ms/step
# Epoch 165/250
# 26/26 - 0s - loss: 0.5363 - accuracy: 0.7393 - 74ms/epoch - 3ms/step
# Epoch 166/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7399 - 100ms/epoch - 4ms/step
# Epoch 167/250
# 26/26 - 0s - loss: 0.5358 - accuracy: 0.7376 - 84ms/epoch - 3ms/step
# Epoch 168/250
# 26/26 - 0s - loss: 0.5367 - accuracy: 0.7385 - 87ms/epoch - 3ms/step
# Epoch 169/250
# 26/26 - 0s - loss: 0.5365 - accuracy: 0.7387 - 73ms/epoch - 3ms/step
# Epoch 170/250
# 26/26 - 0s - loss: 0.5361 - accuracy: 0.7390 - 71ms/epoch - 3ms/step
# Epoch 171/250
# 26/26 - 0s - loss: 0.5360 - accuracy: 0.7381 - 72ms/epoch - 3ms/step
# Epoch 172/250
# 26/26 - 0s - loss: 0.5358 - accuracy: 0.7392 - 78ms/epoch - 3ms/step
# Epoch 173/250
# 26/26 - 0s - loss: 0.5372 - accuracy: 0.7379 - 70ms/epoch - 3ms/step
# Epoch 174/250
# 26/26 - 0s - loss: 0.5356 - accuracy: 0.7376 - 68ms/epoch - 3ms/step
# Epoch 175/250
# 26/26 - 0s - loss: 0.5365 - accuracy: 0.7384 - 65ms/epoch - 2ms/step
# Epoch 176/250
# 26/26 - 0s - loss: 0.5359 - accuracy: 0.7390 - 70ms/epoch - 3ms/step
# Epoch 177/250
# 26/26 - 0s - loss: 0.5354 - accuracy: 0.7394 - 66ms/epoch - 3ms/step
# Epoch 178/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7386 - 67ms/epoch - 3ms/step
# Epoch 179/250
# 26/26 - 0s - loss: 0.5354 - accuracy: 0.7392 - 63ms/epoch - 2ms/step
# Epoch 180/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7401 - 66ms/epoch - 3ms/step
# Epoch 181/250
# 26/26 - 0s - loss: 0.5355 - accuracy: 0.7390 - 62ms/epoch - 2ms/step
# Epoch 182/250
# 26/26 - 0s - loss: 0.5356 - accuracy: 0.7390 - 71ms/epoch - 3ms/step
# Epoch 183/250
# 26/26 - 0s - loss: 0.5362 - accuracy: 0.7378 - 78ms/epoch - 3ms/step
# Epoch 184/250
# 26/26 - 0s - loss: 0.5353 - accuracy: 0.7395 - 88ms/epoch - 3ms/step
# Epoch 185/250
# 26/26 - 0s - loss: 0.5358 - accuracy: 0.7398 - 81ms/epoch - 3ms/step
# Epoch 186/250
# 26/26 - 0s - loss: 0.5368 - accuracy: 0.7386 - 63ms/epoch - 2ms/step
# Epoch 187/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7389 - 65ms/epoch - 2ms/step
# Epoch 188/250
# 26/26 - 0s - loss: 0.5358 - accuracy: 0.7392 - 70ms/epoch - 3ms/step
# Epoch 189/250
# 26/26 - 0s - loss: 0.5351 - accuracy: 0.7388 - 68ms/epoch - 3ms/step
# Epoch 190/250
# 26/26 - 0s - loss: 0.5356 - accuracy: 0.7392 - 72ms/epoch - 3ms/step
# Epoch 191/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7400 - 72ms/epoch - 3ms/step
# Epoch 192/250
# 26/26 - 0s - loss: 0.5352 - accuracy: 0.7400 - 75ms/epoch - 3ms/step
# Epoch 193/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7393 - 78ms/epoch - 3ms/step
# Epoch 194/250
# 26/26 - 0s - loss: 0.5353 - accuracy: 0.7390 - 81ms/epoch - 3ms/step
# Epoch 195/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7393 - 77ms/epoch - 3ms/step
# Epoch 196/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7392 - 81ms/epoch - 3ms/step
# Epoch 197/250
# 26/26 - 0s - loss: 0.5351 - accuracy: 0.7383 - 89ms/epoch - 3ms/step
# Epoch 198/250
# 26/26 - 0s - loss: 0.5355 - accuracy: 0.7386 - 78ms/epoch - 3ms/step
# Epoch 199/250
# 26/26 - 0s - loss: 0.5347 - accuracy: 0.7399 - 71ms/epoch - 3ms/step
# Epoch 200/250
# 26/26 - 0s - loss: 0.5353 - accuracy: 0.7384 - 76ms/epoch - 3ms/step
# Epoch 201/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7385 - 79ms/epoch - 3ms/step
# Epoch 202/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7394 - 71ms/epoch - 3ms/step
# Epoch 203/250
# 26/26 - 0s - loss: 0.5357 - accuracy: 0.7384 - 68ms/epoch - 3ms/step
# Epoch 204/250
# 26/26 - 0s - loss: 0.5359 - accuracy: 0.7387 - 72ms/epoch - 3ms/step
# Epoch 205/250
# 26/26 - 0s - loss: 0.5347 - accuracy: 0.7400 - 68ms/epoch - 3ms/step
# Epoch 206/250
# 26/26 - 0s - loss: 0.5352 - accuracy: 0.7393 - 67ms/epoch - 3ms/step
# Epoch 207/250
# 26/26 - 0s - loss: 0.5354 - accuracy: 0.7397 - 72ms/epoch - 3ms/step
# Epoch 208/250
# 26/26 - 0s - loss: 0.5351 - accuracy: 0.7398 - 79ms/epoch - 3ms/step
# Epoch 209/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7389 - 84ms/epoch - 3ms/step
# Epoch 210/250
# 26/26 - 0s - loss: 0.5352 - accuracy: 0.7397 - 83ms/epoch - 3ms/step
# Epoch 211/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7391 - 74ms/epoch - 3ms/step
# Epoch 212/250
# 26/26 - 0s - loss: 0.5343 - accuracy: 0.7409 - 74ms/epoch - 3ms/step
# Epoch 213/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7385 - 71ms/epoch - 3ms/step
# Epoch 214/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7394 - 78ms/epoch - 3ms/step
# Epoch 215/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7402 - 75ms/epoch - 3ms/step
# Epoch 216/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7398 - 70ms/epoch - 3ms/step
# Epoch 217/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7394 - 73ms/epoch - 3ms/step
# Epoch 218/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7392 - 64ms/epoch - 2ms/step
# Epoch 219/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7396 - 71ms/epoch - 3ms/step
# Epoch 220/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7404 - 74ms/epoch - 3ms/step
# Epoch 221/250
# 26/26 - 0s - loss: 0.5347 - accuracy: 0.7396 - 76ms/epoch - 3ms/step
# Epoch 222/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7401 - 74ms/epoch - 3ms/step
# Epoch 223/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7402 - 75ms/epoch - 3ms/step
# Epoch 224/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7404 - 69ms/epoch - 3ms/step
# Epoch 225/250
# 26/26 - 0s - loss: 0.5349 - accuracy: 0.7398 - 74ms/epoch - 3ms/step
# Epoch 226/250
# 26/26 - 0s - loss: 0.5342 - accuracy: 0.7386 - 72ms/epoch - 3ms/step
# Epoch 227/250
# 26/26 - 0s - loss: 0.5349 - accuracy: 0.7395 - 81ms/epoch - 3ms/step
# Epoch 228/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7392 - 76ms/epoch - 3ms/step
# Epoch 229/250
# 26/26 - 0s - loss: 0.5347 - accuracy: 0.7400 - 76ms/epoch - 3ms/step
# Epoch 230/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7390 - 67ms/epoch - 3ms/step
# Epoch 231/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7385 - 65ms/epoch - 3ms/step
# Epoch 232/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7393 - 65ms/epoch - 2ms/step
# Epoch 233/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7397 - 62ms/epoch - 2ms/step
# Epoch 234/250
# 26/26 - 0s - loss: 0.5351 - accuracy: 0.7381 - 74ms/epoch - 3ms/step
# Epoch 235/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7395 - 75ms/epoch - 3ms/step
# Epoch 236/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7399 - 74ms/epoch - 3ms/step
# Epoch 237/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7397 - 78ms/epoch - 3ms/step
# Epoch 238/250
# 26/26 - 0s - loss: 0.5355 - accuracy: 0.7375 - 75ms/epoch - 3ms/step
# Epoch 239/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7394 - 75ms/epoch - 3ms/step
# Epoch 240/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7399 - 73ms/epoch - 3ms/step
# Epoch 241/250
# 26/26 - 0s - loss: 0.5342 - accuracy: 0.7392 - 80ms/epoch - 3ms/step
# Epoch 242/250
# 26/26 - 0s - loss: 0.5350 - accuracy: 0.7378 - 64ms/epoch - 2ms/step
# Epoch 243/250
# 26/26 - 0s - loss: 0.5346 - accuracy: 0.7404 - 61ms/epoch - 2ms/step
# Epoch 244/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7409 - 60ms/epoch - 2ms/step
# Epoch 245/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7404 - 60ms/epoch - 2ms/step
# Epoch 246/250
# 26/26 - 0s - loss: 0.5348 - accuracy: 0.7395 - 59ms/epoch - 2ms/step
# Epoch 247/250
# 26/26 - 0s - loss: 0.5341 - accuracy: 0.7395 - 58ms/epoch - 2ms/step
# Epoch 248/250
# 26/26 - 0s - loss: 0.5345 - accuracy: 0.7407 - 62ms/epoch - 2ms/step
# Epoch 249/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7393 - 64ms/epoch - 2ms/step
# Epoch 250/250
# 26/26 - 0s - loss: 0.5344 - accuracy: 0.7404 - 61ms/epoch - 2ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5540 - accuracy: 0.7292 - 498ms/epoch - 2ms/step
# Loss: 0.5539643168449402, Accuracy: 0.7292128205299377

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
